# %%
import pandas
import pandas as pd
df=pd.read_excel(r"D:\Bujji\bujji\friends names.xlsx")
df
# Out:
#     friends      quality
# 0  prasanna  intilligent
# 1     swati       active
# 2     durga  intilligent
# 3   jayasri       active
# 4   shabana       silent
# 5   shahena       silent
# 6    parvin       active
# 7   santosh          joy
# 8      kaza         good
# 9     mouni        funny

# %%
df=pd.DataFrame(df)
df
# Out:
#     friends      quality
# 0  prasanna  intilligent
# 1     swati       active
# 2     durga  intilligent
# 3   jayasri       active
# 4   shabana       silent
# 5   shahena       silent
# 6    parvin       active
# 7   santosh          joy
# 8      kaza         good
# 9     mouni        funny

# %%
df.head()
# Out:
#     friends      quality
# 0  prasanna  intilligent
# 1     swati       active
# 2     durga  intilligent
# 3   jayasri       active
# 4   shabana       silent

# %%
df.tail()
# Out:
#    friends quality
# 5  shahena  silent
# 6   parvin  active
# 7  santosh     joy
# 8     kaza    good
# 9    mouni   funny

# %%
df.dtypes
# Out:
# friends    object
# quality    object
# dtype: object

# %%
df.shape
# Out:
# (10, 2)

# %%
df.columns
# Out:
# Index(['friends', 'quality'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   friends  10 non-null     object
#  1   quality  10 non-null     object
# dtypes: object(2)
# memory usage: 288.0+ bytes

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# ------->Pandas Filters

# %%
import pandas
import pandas as pd
df1=pd.read_excel(r"D:\Bujji\anna_canteen (1).xlsx",sheet_name="Sheet6")
df1
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 0              300                  Gow_down-1             Canteen-1
# 1              300                  Gow_down-1             Canteen-2
# 2              300                  Gow_down-1             Canteen-3
# 3              300                  Gow_down-1             Canteen-4
# 4              300                  Gow_down-2             Canteen-5
# 5              300                  Gow_down-2             Canteen-6
# 6              300                  Gow_down-2             Canteen-7
# 7              300                  Gow_down-2             Canteen-8
# 8              300                  Gow_down-2             Canteen-9
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 0                            320                     300
# 1                            320                     300
# 2                            320                     300
# ...

# %%
#-------->>Basic checks

# %%
df1=pd.DataFrame(df1)
df1
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 0              300                  Gow_down-1             Canteen-1
# 1              300                  Gow_down-1             Canteen-2
# 2              300                  Gow_down-1             Canteen-3
# 3              300                  Gow_down-1             Canteen-4
# 4              300                  Gow_down-2             Canteen-5
# 5              300                  Gow_down-2             Canteen-6
# 6              300                  Gow_down-2             Canteen-7
# 7              300                  Gow_down-2             Canteen-8
# 8              300                  Gow_down-2             Canteen-9
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 0                            320                     300
# 1                            320                     300
# 2                            320                     300
# ...

# %%
df1.head()
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 0              300                  Gow_down-1             Canteen-1
# 1              300                  Gow_down-1             Canteen-2
# 2              300                  Gow_down-1             Canteen-3
# 3              300                  Gow_down-1             Canteen-4
# 4              300                  Gow_down-2             Canteen-5
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 0                            320                     300
# 1                            320                     300
# 2                            320                     300
# 3                            320                     300
# 4                            320                     300
#
#    No_of_ Feedbacks Received  Rating Food weight_GowDown  \
# 0                        120       4               270kg
# 1                        160       4               270kg
# ...

# %%
df1.tail()
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 4              300                  Gow_down-2             Canteen-5
# 5              300                  Gow_down-2             Canteen-6
# 6              300                  Gow_down-2             Canteen-7
# 7              300                  Gow_down-2             Canteen-8
# 8              300                  Gow_down-2             Canteen-9
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 4                            320                     300
# 5                            320                     270
# 6                            320                     300
# 7                            320                     300
# 8                            320                     300
#
#    No_of_ Feedbacks Received  Rating Food weight_GowDown  \
# 4                        180       3               270kg
# 5                        250       4               270kg
# ...

# %%
df1.shape
# Out:
# (9, 13)

# %%
df1.columns
# Out:
# Index(['No_of_ Customer', 'No_of_ Food Delivery_ Units',
#        'No_of_ Anna_ Canteens', 'Total_ Available_ Food Plates',
#        'No_of _Plates Consumed', 'No_of_ Feedbacks Received', 'Rating',
#        'Food weight_GowDown', 'Food weight Anna_Canteen', 'No_of_ Donations',
#        'Total _Donation Amount', 'No_of _Employs', 'Total _Generated_ Tokens'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   No_of_ Customer                9 non-null      int64
#  1   No_of_ Food Delivery_ Units    9 non-null      object
#  2   No_of_ Anna_ Canteens          9 non-null      object
#  3   Total_ Available_ Food Plates  9 non-null      int64
#  4   No_of _Plates Consumed         9 non-null      int64
#  5   No_of_ Feedbacks Received      9 non-null      int64
#  6   Rating                         9 non-null      int64
#  7   Food weight_GowDown            9 non-null      object
#  8   Food weight Anna_Canteen       9 non-null      object
#  9   No_of_ Donations               9 non-null      int64
#  10  Total _Donation Amount         9 non-null      int64
#  11  No_of _Employs                 9 non-null      int64
# ...

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
df1.dtypes
# Out:
# No_of_ Customer                   int64
# No_of_ Food Delivery_ Units      object
# No_of_ Anna_ Canteens            object
# Total_ Available_ Food Plates     int64
# No_of _Plates Consumed            int64
# No_of_ Feedbacks Received         int64
# Rating                            int64
# Food weight_GowDown              object
# Food weight Anna_Canteen         object
# No_of_ Donations                  int64
# Total _Donation Amount            int64
# No_of _Employs                    int64
# Total _Generated_ Tokens          int64
# dtype: object

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
#-------->>>>Filters

# %%
df1['No_of_ Customer'].unique()
# Out:
# array([300], dtype=int64)

# %%
#---syntax---one colum lo one value

# %%
df1[df1['No_of_ Anna_ Canteens']=='Canteen-4']
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 3              300                  Gow_down-1             Canteen-4
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 3                            320                     300
#
#    No_of_ Feedbacks Received  Rating Food weight_GowDown  \
# 3                        200       5               270kg
#
#   Food weight Anna_Canteen  No_of_ Donations  Total _Donation Amount  \
# 3                    270kg               121                    3000
#
#    No_of _Employs  Total _Generated_ Tokens
# 3              12                       300

# %%
#---syntax---two colums lo values and condition use

# %%
df1[(df1['No_of_ Donations']==78) | (df1['No_of_ Feedbacks Received']==250)]
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 5              300                  Gow_down-2             Canteen-6
# 6              300                  Gow_down-2             Canteen-7
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 5                            320                     270
# 6                            320                     300
#
#    No_of_ Feedbacks Received  Rating Food weight_GowDown  \
# 5                        250       4               270kg
# 6                        250       5               270kg
#
#   Food weight Anna_Canteen  No_of_ Donations  Total _Donation Amount  \
# 5                    270kg                78                    6500
# 6                    270kg                12                    1500
#
#    No_of _Employs  Total _Generated_ Tokens
# 5              18                       300
# 6              11                       300

# %%
df1[~(df1['No_of_ Donations']==78) | (df1['No_of_ Feedbacks Received']==250)]
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 0              300                  Gow_down-1             Canteen-1
# 1              300                  Gow_down-1             Canteen-2
# 2              300                  Gow_down-1             Canteen-3
# 3              300                  Gow_down-1             Canteen-4
# 4              300                  Gow_down-2             Canteen-5
# 5              300                  Gow_down-2             Canteen-6
# 6              300                  Gow_down-2             Canteen-7
# 7              300                  Gow_down-2             Canteen-8
# 8              300                  Gow_down-2             Canteen-9
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 0                            320                     300
# 1                            320                     300
# 2                            320                     300
# ...

# %%
# APPEND

# %%
import pandas as pd
c=pd.concat([df,df1],axis=0)
c
# Out:
#     friends      quality  No_of_ Customer No_of_ Food Delivery_ Units  \
# 0  prasanna  intilligent              NaN                         NaN
# 1     swati       active              NaN                         NaN
# 2     durga  intilligent              NaN                         NaN
# 3   jayasri       active              NaN                         NaN
# 4   shabana       silent              NaN                         NaN
# 5   shahena       silent              NaN                         NaN
# 6    parvin       active              NaN                         NaN
# 7   santosh          joy              NaN                         NaN
# 8      kaza         good              NaN                         NaN
# 9     mouni        funny              NaN                         NaN
# 0       NaN          NaN            300.0                  Gow_down-1
# 1       NaN          NaN            300.0                  Gow_down-1
# ...

# %%
d=pd.read_excel(r"C:\Users\hp\bujji\Boys names.xlsx")
d
# Out:
#   Friends names      quality
# 0       santosh  intilligent
# 1     govardhan        funny
# 2         sunil          joy
# 3         reddy       clever
# 4          raja       active
# 5         dessy        funny

# %%
pd.concat([df,d],axis=1)
# Out:
#     friends      quality Friends names      quality
# 0  prasanna  intilligent       santosh  intilligent
# 1     swati       active     govardhan        funny
# 2     durga  intilligent         sunil          joy
# 3   jayasri       active         reddy       clever
# 4   shabana       silent          raja       active
# 5   shahena       silent         dessy        funny
# 6    parvin       active           NaN          NaN
# 7   santosh          joy           NaN          NaN
# 8      kaza         good           NaN          NaN
# 9     mouni        funny           NaN          NaN

# %%
pd.concat([df,d],axis=0)
# Out:
#     friends      quality Friends names
# 0  prasanna  intilligent           NaN
# 1     swati       active           NaN
# 2     durga  intilligent           NaN
# 3   jayasri       active           NaN
# 4   shabana       silent           NaN
# 5   shahena       silent           NaN
# 6    parvin       active           NaN
# 7   santosh          joy           NaN
# 8      kaza         good           NaN
# 9     mouni        funny           NaN
# 0       NaN  intilligent       santosh
# 1       NaN        funny     govardhan
# 2       NaN          joy         sunil
# 3       NaN       clever         reddy
# 4       NaN       active          raja
# 5       NaN        funny         dessy
